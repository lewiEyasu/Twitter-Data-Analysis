# %%
import pandas as pd

# %%
df = pd.read_csv('/media/levi/12/Compressed/file1_name.csv')
df.head()
# Out:
#                        created_at  \
# 0  Sun Aug 07 22:31:20 +0000 2022
# 1  Sun Aug 07 22:31:07 +0000 2022
# 2  Sun Aug 07 22:31:06 +0000 2022
# 3  Sun Aug 07 22:31:04 +0000 2022
# 4  Sun Aug 07 22:31:02 +0000 2022
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/android" ...
#
#                                        original_text      polarity  \
# 0  RT @i_ameztoy: Extra random image (I):\n\nLets... -1.250000e-01
# 1  China even cut off communication, they don't a...  0.000000e+00
# 2  Putin to #XiJinping : I told you my friend, Ta...  1.000000e-01
# 3  RT @ChinaUncensored: I’m sorry, I thought Taiw... -6.938894e-18
# 4  RT @benedictrogers: We must not let this happe...  2.000000e-01
#
# ...

# %%
for i in range(5):
    #print((df.subjectivity[i]), end=”,“)
    print(df.friends_count[i],end=",")
# Out:
# 20497,85,85,910,207,

# %%
for i in range(5):
   print(i,end=",")
# Out:
# 0,1,2,3,4,
